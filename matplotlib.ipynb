# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **散点图**

# %%
n=100
x=np.random.randn(n)
y=np.random.randn(n)
plt.scatter(x,y,s=20,c="r",marker="o",alpha=0.5)
plt.show()

# %% [markdown]
#  *  颜色 c
#  * 大小 s(面积)
#  * 透明度 alpha
#  * 点的形状 marker

# %% [markdown]
# **折线图**
