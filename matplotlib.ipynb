# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 散点图

# %%
n=100
x=np.random.randn(n)
y=np.random.randn(n)
plt.scatter(x,y,s=20,c="r",marker="o",alpha=0.5)
plt.show()

# %% [markdown]
#  *  颜色 c
#  * 大小 s(面积)
#  * 透明度 alpha
#  * 点的形状 marker

# %% [markdown]
# ### 折线图

# %%
x=np.linspace(-10,10,5)
y=x**2
plt.plot(x,y,color="red",linestyle="--",linewidth=2,marker=">",markersize=6)
plt.show()

# %% [markdown]
# `plt.plot_date(date,open)`专门来画以时间为变量的折线图

# %% [markdown]
# ### 条形图

# %%
x=np.arange(5)
y=[12,14,18,20,17]
plt.bar(x,y,alpha=0.8,width=0.8,color="blue",edgecolor="red",lw=1,label="one")
plt.legend(loc="upper-right")
plt.show()

# %% [markdown]
# `matplotlib.pyplot.bar(left, height, alpha=1, width=0.8, color=, edgecolor=, label=, lw=3)`

# %% [markdown]
# * `left`：x轴的位置序列，一般采用arange函数产生一个序列；
# * `height`：y轴的数值序列，也就是柱形图的高度，一般就是我们需要展示的数据；
# * `alpha`：透明度
# * `width`：为柱形图的宽度，一般这是为0.8即可；
# * `color`或`facecolor`：柱形图填充的颜色；
# * `edgecolor`：图形边缘颜色
# * `label`：解释每个图像代表的含义
# * `linewidth` or `linewidths` or `lw`：边缘or线的宽度

# %%
x=np.arange(5)
y=[12,14,18,20,17]
plt.barh(x,y,alpha=0.8,height=0.8,color="blue",edgecolor="red",lw=1,label="one")
plt.legend(loc="upper-right")
plt.show()

# %%
x=np.arange(5)
y1=[12,14,18,20,17]
y2=[10,23,14,18,19]
width=0.3
plt.bar(x,y1,width=width,color="blue")
plt.bar(x+width,y2,width=width,color="red")
plt.show()

# %%
x=np.arange(5)
y1=[12,14,18,20,17]
y2=[10,23,14,18,19]
plt.bar(x,y1,color="blue")
plt.bar(x,y2,bottom=y1,color="red")
plt.show()

# %%
x=np.arange(5)
y1=[12,14,18,20,17]
y2=[10,23,14,18,19]
plt.barh(x,y1,color="blue")
plt.barh(x,y2,left=y1,color="red")
plt.show()

# %% [markdown]
# ### 直方图

# %%
mean=10
var=5
x=mean+var*np.random.randn(1000)
n, bins, patches=plt.hist(x,bins=20,color="red",density=1)
plt.plot(bins[:20],n,linestyle="--")
plt.show()

# %% [markdown]
# `matplotlib.pyplot.hist(x, bins=None, range=None, density=None, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, data=None, **kwargs)`

# %%
x=2+np.random.randn(1000)
y=3+np.random.randn(1000)
plt.hist2d(x,y,bins=40)
plt.show()

# %% [markdown]
# ### 饼图

# %%
labels=["A","B","C","D","E"]
values=[13,24,16,18,45]
plt.pie(values,autopct="%.2f%%",explode=[0,0,0,0,0.1],labels=labels,shadow=True)
plt.show()

# %% [markdown]
# `matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, hold=None, data=None)`
#
# * `x`：数组。输入的数据用于创建一个饼图。
# * `explode`：数组，可选参数，默认为None。如果不是None，是一个长度与x相同长度的数组，用来指定每部分的偏移量。例如：`explode=[0,0,0.2,0,0]`，第二个饼块被拖出。
# * `labels`：列表，可选参数，默认为：None。一个字符串序列作为每个饼块的标记。
# * `colors`：数组，可选参数，默认为：None。用来标注每块饼图的matplotlib颜色参数序列。如果为None，将使用当前活动环的颜色。
# * `autopct`：默认是None，字符串或函数，可选参数。如果不是None，是一个字符串或函数用带有数值饼图标注。
# * `pctdistance`：浮点数，可选参数，默认值：0.6。每个饼切片的中心和通过autopct生成的文本开始之间的比例。如果autopct是None，被忽略。
# * `shadow`：布尔值，可选参数，默认值：False。在饼图下面画一个阴影。
# * `labeldistance`：浮点数，可选参数，默认值：1.1。被画饼标记的直径。
# * `startangle`：浮点类型，可选参数，默认：None。如果不是None，从x轴逆时针旋转饼图的开始角度。
# * `radius`：浮点类型，可选参数，默认为：None。饼图的半径，如果半径是None，将被设置成1。
# * `counterclock`：布尔值，可选参数，默认为：None。指定指针方向，顺时针或者逆时针。
# * `wedgeprops`：字典类型，可选参数，默认值：None。参数字典传递给wedge对象用来画一个饼图。例如：`wedgeprops={'linewidth':3}`设置wedge线宽为3。
# * `textprops`：字典类型，可选参数，默认值为：None。传递给text对象的字典参数。
# * `center`：浮点类型的列表，可选参数，默认值：(0,0)。图标中心位置。
# * `frame`：布尔类型，可选参数，默认值：False。如果是true，绘制带有表的轴框架。
# * `rotatelabels`：布尔类型，可选参数，默认为：False。如果为True，旋转每个label到指定的角度。
# **返回值：**
# * `patches`：列表。matplotlib.patches.Wedge实例列表。
# * `text`：列表。matplotlib.text.Text实例label的列表。
# * `autotexts`：列表。A是数字标签的Text实例列表。仅当参数autopct不为None时才返回

# %% [markdown]
# ### 箱型图

# %%
np.random.seed(100)
data=np.random.normal(size=1000,loc=0,scale=1)
plt.boxplot(data,sym="*",whis=1.5,notch=True)
plt.show()

# %% [markdown]
# * `x`	指定要绘制箱线图的数据；
# * `showcaps`	是否显示箱线图顶端和末端的两条线
# * `notch`	是否是凹口的形式展现箱线图
# * `showbox`	是否显示箱线图的箱体
# * `sym`	指定异常点的形状
# * `showfliers`	是否显示异常值
# * `vert`	是否需要将箱线图垂直摆放
# * `boxprops`	设置箱体的属性，如边框色，填充色等；
# * `whis`	指定上下须与上下四分位的距离
# * `labels`	为箱线图添加标签
# * `positions`	指定箱线图的位置
# * `filerprops`	设置异常值的属性
# * `widths`	指定箱线图的宽度
# * `medianprops`	设置中位数的属性
# * `patch_artist	`是否填充箱体的颜色；
# * `meanprops`	设置均值的属性
# * `meanline`	是否用线的形式表示均值
# * `capprops`	设置箱线图顶端和末端线条的属性
# * `showmeans`	是否显示均值
# * `whiskerprops`	设置须的属性

# %%
np.random.seed(100)
data=np.random.normal(size=(300,4),loc=0,scale=1)
labels=["A","B","C","D"]
plt.boxplot(data,labels=labels)
plt.show()

# %% [markdown]
# ### 颜色

# %% [markdown]
# **常用颜色**：
# * b:blue
# * g:green
# * r:red
# * c:cyan
# * m:magenta
# * y:yellow
# * k:black
# * w:white
#
# **灰度表示**
# `color=0.5`
#
# **16进制表示**
# `color="#FF00FF"`
#
# **RGB元组表示**
# `color=(0.1,0.2,0.3)`

# %%
y=np.arange(5)
plt.plot(y,color="g")
plt.plot(y+1,color="0.2")
plt.plot(y+2,color="#FF00FF")
plt.plot(y+3,color=(0.5,0,0.3))

# %% [markdown]
# ### 样式字符串
#
# `"bo--"`:将颜色，点，线样式组合在一起的字符串

# %%
y=np.arange(5)
plt.plot(y,"bo--")
plt.show()

# %% [markdown]
# ### 面向对象

# %%
x=np.arange(10)
y=np.random.randn(len(x))
fig=plt.figure()
ax=fig.add_subplot(111)
plt.plot(x,y)
ax.set_title("test")
plt.show()

# %% [markdown]
# **主要对象**
# * FigureCavas
# * Figure
# * Axes

# %% [markdown]
# #### Axes 对象

# %% [markdown]
# `ax1=fig.add_subplot(2,2,1)`
#
# `ax2=fig.add_subplot(2,2,2)`
#
# `ax3=fig.add_subplot(2,2,3)`
#
# `ax4=fig.add_subplot(2,2,4)`
#
# * 返回Axes对象
# * 参数第一个为总行数，第二个总列数，第三个为子图位置

# %%
x=np.arange(10)
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.plot(x,x)
ax2.plot(x,-x)
ax3.plot(x,x**2)
ax4.plot(x,np.log(x))
plt.show()

# %% [markdown]
# #### Figure 对象

# %%
x=np.arange(10)
fig1=plt.figure()
ax1=fig1.add_subplot(111)
ax1.plot(x,x)
fig2=plt.figure()
ax2=fig2.add_subplot(111)
ax2.plot(x,x**2)
plt.show()

# %% [markdown]
# ### 网格

# %%
x=np.linspace(0,3,100)
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(x,np.log(x))
ax.grid(color="y",linewidth=1,linestyle="-.")
plt.show()

# %% [markdown]
# ###  图例

# %%
x=np.linspace(0,3,100)
plt.plot(x,x,label="Line")
plt.plot(x,x**2,label="squre")
plt.plot(x,np.log(x),label="log")
plt.legend(loc="best",ncol=2)
plt.show()

# %%
x=np.linspace(0,3,100)
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(x,x)
ax.plot(x,x**2)
ax.plot(x,np.log(x))
ax.legend(["Line","squre","log"],loc="best",ncol=2)
plt.show()

# %% [markdown]
# ### 坐标轴

# %% [markdown]
# #### 坐标轴显示范围

# %%
x=np.linspace(-3,3,300)
plt.plot(x,x**3)
plt.axis([-4,4,-30,30])
plt.show()

# %%
x=np.linspace(-3,3,300)
plt.plot(x,x**2)
plt.xlim([-4,4])
plt.ylim(ymin=0)
plt.show()

# %%
x=np.linspace(-2,2,50)
plt.plot(x,np.exp(x))
ax=plt.gca()
ax.locator_params("x",nbins=10)
plt.show()

# %% [markdown]
# #### 坐标轴刻度

# %%
x=np.linspace(-5,5,50)
y=np.exp(x)
plt.plot(x,y)
plt.xticks([-5,-3,-1,1,3,5])
plt.yticks(np.arange(0,160,10))
plt.show()

# %%
plt.plot([1,2,3,4],[13,25,15,14])
plt.xticks([1,2,3,4],["worst","worse","better","best"])
plt.show()

# %%
x=np.arange(-5,5,1)
plt.plot(x,x)
plt.xscale("linear")
plt.yscale("log")
plt.show()

# %% [markdown]
# #### 日期处理

# %%
from datetime import datetime
dates = ["2018-02-01","2018-03-01","2018-04-01","2018-05-01"]
x=[datetime.strptime(i,"%Y-%m-%d").date()  for i in dates]
y=[13,50,18,13]
plt.plot(x,y)
plt.gcf().autofmt_xdate()  #通过 gcf 中的 autofmt_xdate 方法来对日期的显示进行一个旋转。
plt.show()

# %%
import matplotlib
import datetime
start=datetime.datetime(2015,1,1)
stop=datetime.datetime(2016,1,1)
delta=datetime.timedelta(days=1)
dates=matplotlib.dates.drange(start,stop,delta)
y=np.random.randn(len(dates))
plt.plot_date(dates,y,"bo--")
plt.show()

# %%
import matplotlib
import datetime
start=datetime.datetime(2015,1,1)
stop=datetime.datetime(2016,1,1)
delta=datetime.timedelta(days=1)
dates=matplotlib.dates.drange(start,stop,delta)
y=np.random.randn(len(dates))
date_format=matplotlib.dates.DateFormatter("%Y/%m/%d")
ax=plt.gca()
ax.xaxis.set_major_formatter(date_format)
plt.plot_date(dates,y,"bo--")
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# #### 坐标轴名称

# %%
x=np.linspace(-5,5,50)
y=np.sin(x)
plt.xlabel("x",fontsize=20,color="red")
plt.ylabel("$\sin x$")  # TEX
plt.plot(x,y)
plt.show()

# %% [markdown]
# #### 添加坐标轴

# %%
x=np.linspace(0,10,50)
y1=np.log(x)
y2=np.exp(x)
plt.plot(x,y1,color="red")
plt.twinx()
plt.plot(x,y2,color="blue")
plt.show()

# %%
x=np.linspace(0,10,50)
y1=np.log(x)
y2=np.exp(x)
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.plot(x,y1,color="red")
ax1.set_ylabel("Y1")
ax2=ax1.twinx()
ax2.plot(x,y2,color="blue")
ax2.set_ylabel("Y2")
plt.show()

# %%
x=np.linspace(0,10,50)
y1=np.log(x)
y2=np.exp(x)
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.plot(y1,x,color="red")
ax1.set_xlabel("X1")
ax2=ax1.twiny()
ax2.plot(y2,x,color="blue")
ax2.set_xlabel("X2")
plt.show()

# %% [markdown]
# ### 注释

# %%
x=np.arange(-5,5,0.1)
y=x**2
plt.plot(x,y)
plt.annotate("this is the minimum",xy=(0,1),xytext=(-1.5,10),arrowprops=dict(facecolor="r",frac=0.5,headwidth=20,width=10))
plt.show()

# %% [markdown]
# ### 文字

# %%
x=np.linspace(-4,4,40)
y=x**2
plt.text(-1,6,"fuction:$y=x^2$",family="fantasy",size=15,color="blue",style="italic",weight=1000,bbox=dict(facecolor="red",alpha=0.2))  #weight 0-1000
plt.plot(x,y)
plt.show()

# %%
x=np.random.randn(100)
y=np.random.randn(100)
color=np.random.randn(100)
size=np.pi * (10*np.random.randn(100))**2
plt.scatter(x,y,s=size,c=color,alpha=0.8)
plt.show()

# %% [markdown]
# ### 区域填充

# %%
x=np.linspace(-2*np.pi,4*np.pi,100)
y1=np.sin(x)
y2=np.cos(2*x)
plt.fill(x,y1,"b",alpha=0.3)
plt.fill(x,y2,"r",alpha=0.3)

plt.show()

# %%
x=np.linspace(-2*np.pi,4*np.pi,100)
y1=np.sin(x)
y2=np.cos(2*x)
fig=plt.figure()
ax=plt.gca()
ax.plot(x,y1,"b")
ax.plot(x,y2,"r")
ax.fill_between(x,y1,y2,where=y1>y2,facecolor="yellow",interpolate=True)
ax.fill_between(x,y1,y2,where=y1<=y2,facecolor="cyan",interpolate=True)
plt.show()

# %% [markdown]
# ### 形状

# %%
import matplotlib.patches as mpatches
fig,ax=plt.subplots()
circle=mpatches.Circle([0.2,0.2],0.1) #[0.2,0.2]为圆心位置，0，1为半斤大小
ax.add_patch(circle)
rect=mpatches.Rectangle([0.2,0.8],0.1,0.2,color="red")
ax.add_patch(rect)
polygon=mpatches.RegularPolygon([0.8,0.8],5,0.1,color="cyan")# 位置，多边形边数，半径
ax.add_patch(polygon)
ellipse=mpatches.Ellipse([0.8,0.2],0.2,0.4,color="yellow")
ax.add_patch(ellipse)
plt.axis("equal") #设置x,y轴比例相同
plt.grid()
plt.show()

# %% [markdown]
# ### 美化

# %%
fig,axes=plt.subplots(ncols=2,nrows=2)
ax1,ax2,ax3,ax4=axes.ravel()
x,y=np.random.normal()
